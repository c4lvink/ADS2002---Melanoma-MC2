# %%
import kagglehub
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
kagglehub.login()
# Out:
# ...
# Kaggle credentials set.
# Kaggle credentials successfully validated.

# %%
filepath = "siim-isic-melanoma-classification"
path = kagglehub.competition_download("siim-isic-melanoma-classification", path="train.csv")
train_df = pd.read_csv(path)
# Out:
# ...
# 100%|██████████| 339k/339k [00:00<00:00, 51.5MB/s]
# Extracting zip of train.csv...

# %%
train_df.head()
# Out:
#      image_name  patient_id     sex  age_approx anatom_site_general_challenge  \
# 0  ISIC_2637011  IP_7279968    male        45.0                     head/neck
# 1  ISIC_0015719  IP_3075186  female        45.0               upper extremity
# 2  ISIC_0052212  IP_2842074  female        50.0               lower extremity
# 3  ISIC_0068279  IP_6890425  female        45.0                     head/neck
# 4  ISIC_0074268  IP_8723313  female        55.0               upper extremity
#
#   diagnosis benign_malignant  target
# 0   unknown           benign       0
# 1   unknown           benign       0
# 2     nevus           benign       0
# 3   unknown           benign       0
# 4   unknown           benign       0

# %%
train_df.tail()
# Out:
#          image_name  patient_id   sex  age_approx  \
# 33121  ISIC_9999134  IP_6526534  male        50.0
# 33122  ISIC_9999320  IP_3650745  male        65.0
# 33123  ISIC_9999515  IP_2026598  male        20.0
# 33124  ISIC_9999666  IP_7702038  male        50.0
# 33125  ISIC_9999806  IP_0046310  male        45.0
#
#       anatom_site_general_challenge diagnosis benign_malignant  target
# 33121                         torso   unknown           benign       0
# 33122                         torso   unknown           benign       0
# 33123               lower extremity   unknown           benign       0
# 33124               lower extremity   unknown           benign       0
# 33125                         torso     nevus           benign       0

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33126 entries, 0 to 33125
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   image_name                     33126 non-null  object
#  1   patient_id                     33126 non-null  object
#  2   sex                            33061 non-null  object
#  3   age_approx                     33058 non-null  float64
#  4   anatom_site_general_challenge  32599 non-null  object
#  5   diagnosis                      33126 non-null  object
#  6   benign_malignant               33126 non-null  object
#  7   target                         33126 non-null  int64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 2.0+ MB

# %%
train_df.describe()
# Out:
#          age_approx        target
# count  33058.000000  33126.000000
# mean      48.870016      0.017630
# std       14.380360      0.131603
# min        0.000000      0.000000
# 25%       40.000000      0.000000
# 50%       50.000000      0.000000
# 75%       60.000000      0.000000
# max       90.000000      1.000000

# %%
print("Amount of malignant pics: ", (train_df['target'] == 1).sum())
print("Amount of benign pics: ", (train_df['target'] == 0).sum())
# Out:
# Amount of malignant pics:  584
# Amount of benign pics:  32542

# %%
print("Missing values:\n", train_df.isnull().sum())
# Out:
# Missing values:
#  image_name                         0
# patient_id                         0
# sex                               65
# age_approx                        68
# anatom_site_general_challenge    527
# diagnosis                          0
# benign_malignant                   0
# target                             0
# dtype: int64
# Duplicates: 0

# %%
print("Duplicates:", train_df.duplicated().sum())
# Out:
# Duplicates: 0

# %%
sns.heatmap(train_df.corr(numeric_only=True), annot=True, cmap="coolwarm")
plt.title("Feature Correlation Matrix")
plt.show()
